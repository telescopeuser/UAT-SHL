# %% [markdown]
# ### SHL Project
#
# * simulation module: shl_sm
#
# ### shl_sm required data feeds:
#
# * live bidding price, per second, time series
#
# ### prediction module parameters/csv
#
# * parm_si.csv (seasonality index per second)
#
# * parm_month.csv (parameter like alpha, beta, gamma, etc. per month)

# %% [markdown]
# # SHL Simulation Module: shl_sm

# %% [markdown]
# ### Import useful reference packages

# %%
import pandas as pd

# %% [markdown]
# ### Import SHL Prediction Module: shl_pm

# %%
import shl_pm
# Out:
# +-----------------------------------------------+
# | Loaded SHL Prediction Module                  |
# | Version 0.0.0.1                               |
# +-----------------------------------------------+
#
# +-----------------------------------------------+
# | SHL Prediction Module User Guide              |
# +-----------------------------------------------+
#
# +-----------------------------------------------+
# | Key Function I:
# | shl_initialize(in_ccyy_mm='2017-07')
# +-----------------------------------------------+
#
# This function takes one input. Run this funciton once, before calling shl_predict_price_k_step()
#
# Inputs:
# (1) in_ccyy_mm: the (current) year month for predicting bidding price
#     string, i.e. '2017-07'
#
# Outputs: N.A.
#
# +-----------------------------------------------+
# | Key Function II:
# | shl_predict_price_k_step(in_current_time, in_current_price, in_k_seconds=1, return_value='f_1_step_pred_set_price_rounded')
# +-----------------------------------------------+
#
# This function takes four inputs then returns prediciton values in a python list.
#
# Ensure this function is called 'once and only once' for EVERY second with price, starting from '11:29:00'!
# This is to ensure prediction module could capture all actual prices for internal prediction calculation.
#
# Inputs:
# (1) in_current_time: current time/second of bidding price
#     string, i.e. '11:29:50'
# (2) in_current_price : current bidding price
#     number/integer/float, i.e. 89400
# (3) in_k_seconds : forecast price in the next k seconds
#     integer, default value = 1, i.e. 7
# (4) return_value : return result of predicted price, or predicted set price = predicted price + dynamic increment
#     string, i.e. 89600 predicted price     (return_value = 'f_1_step_pred_price_rounded')
#     string, i.e. 89800 predicted set price (return_value = 'f_1_step_pred_set_price_rounded')
#
# Outputs:
# (1) Returned restuls in python list
#     list of integer , i.e. [89800] (in_k_seconds = 1)
#     list of integers, i.e. [89800, 89900, 89900, 90000, 90100, 90100, 90200] (in_k_seconds = 7)

# %% [markdown]
# ### shl_sm parameters:

# %% [markdown]
# ### shl_sm simulated real time per second price ata, fetch from csv:

# %%
## which month to predictsimulate?

# shl_sm_parm_ccyy_mm = '2017-04'
# shl_sm_parm_ccyy_mm_offset = 1647

# shl_sm_parm_ccyy_mm = '2017-05'
# shl_sm_parm_ccyy_mm_offset = 1708

# shl_sm_parm_ccyy_mm = '2017-06'
# shl_sm_parm_ccyy_mm_offset = 1769

# shl_sm_parm_ccyy_mm = '2017-07'
# shl_sm_parm_ccyy_mm_offset = 1830

# shl_sm_parm_ccyy_mm = '2017-08'
# shl_sm_parm_ccyy_mm_offset = 1830+61

shl_sm_parm_ccyy_mm = '2017-09'
shl_sm_parm_ccyy_mm_offset = 1830+61*2

# shl_sm_parm_ccyy_mm = '2017-10'
# shl_sm_parm_ccyy_mm_offset = 1830+61*3

# shl_sm_parm_ccyy_mm = '2017-11'
# shl_sm_parm_ccyy_mm_offset = 1830+61*4

# shl_sm_parm_ccyy_mm = '2017-12'
# shl_sm_parm_ccyy_mm_offset = 1830+61*5

#----------------------------------

shl_sm_data = pd.read_csv('shl_sm_data/shl_sm_data.csv') 
shl_sm_data
# Out:
#       ccyy-mm      time  bid-price
# 0     2015-01  11:29:00      74000
# 1     2015-01  11:29:01      74000
# 2     2015-01  11:29:02      74000
# 3     2015-01  11:29:03      74000
# 4     2015-01  11:29:04      74000
# 5     2015-01  11:29:05      74000
# 6     2015-01  11:29:06      74000
# 7     2015-01  11:29:07      74000
# 8     2015-01  11:29:08      74000
# 9     2015-01  11:29:09      74000
# 10    2015-01  11:29:10      74000
# 11    2015-01  11:29:11      74000
# 12    2015-01  11:29:12      74000
# 13    2015-01  11:29:13      74000
# 14    2015-01  11:29:14      74000
# 15    2015-01  11:29:15      74000
# 16    2015-01  11:29:16      74000
# 17    2015-01  11:29:17      74000
# 18    2015-01  11:29:18      74000
# 19    2015-01  11:29:19      74000
# 20    2015-01  11:29:20      74000
# 21    2015-01  11:29:21      74000
# 22    2015-01  11:29:22      74000
# 23    2015-01  11:29:23      74000
# 24    2015-01  11:29:24      74000
# 25    2015-01  11:29:25      74000
# 26    2015-01  11:29:26      74000
# 27    2015-01  11:29:27      74000
# 28    2015-01  11:29:28      74000
# 29    2015-01  11:29:29      74000
# ...       ...       ...        ...
# 2166  2017-12  11:29:31      90500
# 2167  2017-12  11:29:32      90500
# 2168  2017-12  11:29:33      90500
# 2169  2017-12  11:29:34      90500
# 2170  2017-12  11:29:35      90500
# 2171  2017-12  11:29:36      90600
# 2172  2017-12  11:29:37      90600
# 2173  2017-12  11:29:38      90600
# 2174  2017-12  11:29:39      90700
# 2175  2017-12  11:29:40      90700
# 2176  2017-12  11:29:41      90700
# 2177  2017-12  11:29:42      90700
# 2178  2017-12  11:29:43      90700
# 2179  2017-12  11:29:44      90800
# 2180  2017-12  11:29:45      90800
# 2181  2017-12  11:29:46      90800
# 2182  2017-12  11:29:47      90900
# 2183  2017-12  11:29:48      91000
# 2184  2017-12  11:29:49      91100
# 2185  2017-12  11:29:50      91100
# 2186  2017-12  11:29:51      91100
# 2187  2017-12  11:29:52      91100
# 2188  2017-12  11:29:53      91100
# 2189  2017-12  11:29:54      91200
# 2190  2017-12  11:29:55      91200
# 2191  2017-12  11:29:56      91200
# 2192  2017-12  11:29:57      91300
# 2193  2017-12  11:29:58      91300
# 2194  2017-12  11:29:59      91400
# 2195  2017-12  11:30:00      91600
#
# [2196 rows x 3 columns]

# %% [markdown]
# ### shl_pm Initialization

# %%
shl_pm.shl_initialize(shl_sm_parm_ccyy_mm)
# Out:
# +-----------------------------------------------+
# | shl_initialize()                              |
# +-----------------------------------------------+
#
# shl_global_parm_ccyy_mm           : 2017-09
# -------------------------------------------------
# shl_global_parm_alpha             : 0.848823804527792
# shl_global_parm_beta              : 0.001000000000000
# shl_global_parm_gamma             : 0.149949473217226
# shl_global_parm_short_weight      : 0.1250000000
# shl_global_parm_short_weight_ratio: 0.0000000000
# shl_global_parm_sec57_weight      : 0.5000000000
# shl_global_parm_month_weight      : 0.9000000000
# shl_global_parm_dynamic_increment : 300
# -------------------------------------------------
#
# prediction results dataframe: shl_data_pm_1_step
# Empty DataFrame
# Columns: []
# Index: []
#
# prediction results dataframe: shl_data_pm_k_step
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Upon receiving 11:29:00 second price, to predict till 11:29:49 <- one-step forward price forecasting

for i in range(shl_sm_parm_ccyy_mm_offset, shl_sm_parm_ccyy_mm_offset+50): # use csv data as simulatino
# for i in range(shl_sm_parm_ccyy_mm_offset, shl_sm_parm_ccyy_mm_offset+55): # use csv data as simulatino
    print('\n<<<< Record No.: %5d >>>>' % i)
    print(shl_sm_data['ccyy-mm'][i]) # format: ccyy-mm
    print(shl_sm_data['time'][i]) # format: hh:mm:ss
    print(shl_sm_data['bid-price'][i]) # format: integer
    
######################################################################################################################    
#   call prediction function, returned result is in 'list' format, i.e. [89400]  
    shl_sm_prediction_list_local_1 = shl_pm.shl_predict_price_k_step(shl_sm_data['time'][i], shl_sm_data['bid-price'][i],1) # <- one-step forward price forecasting
    print(shl_sm_prediction_list_local_1)
######################################################################################################################
# Out:
# <<<< Record No.:  1952 >>>>
# 2017-09
# 11:29:00
# 90400
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:00
# in_current_price  : 90400.000000
# *INFO* At time [ 11:29:00 ] Set shl_global_parm_base_price : 90399
# *INFO* f_current_datetime   : 2017-09 11:29:00
# *INFO* f_current_si         : 0.0020000000
# *INFO* f_current_price4pm   : 1
# *INFO* f_current_price4pmsi : 500.0000000000
# *INFO* f_1_step_time        : 11:29:01
# *INFO* f_1_step_si          : 0.0220000000
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [90700]
# [90700]
#
# <<<< Record No.:  1953 >>>>
# 2017-09
# 11:29:01
# 90400
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:01
# in_current_price  : 90400.000000
# *INFO* f_current_datetime   : 2017-09 11:29:01
# *INFO* f_current_si         : 0.0220000000
# *INFO* f_current_price4pm   : 1
# *INFO* f_current_price4pmsi : 45.4545454545
# *INFO* f_1_step_time        : 11:29:02
# *INFO* f_1_step_si          : 0.0300000000
#      previous_pred_les_level  : 500.0000000000
#      previous_pred_les_trend  : 0.0000000000
#      f_1_step_pred_les_level  : 114.1709979419
#      f_1_step_pred_les_trend  : -0.3858290021
#      f_1_step_pred_les        : 113.7851689399
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 113.7851689399
#      f_1_step_pred_price_inc          : 3.4135550682
#      f_1_step_pred_price              : 90402.4135550682
#      f_1_step_pred_price_rounded      : 90400
#      f_1_step_pred_set_price_rounded  : 90700
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [90700]
# [90700]
#
# <<<< Record No.:  1954 >>>>
# 2017-09
# 11:29:02
# 90400
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:02
# in_current_price  : 90400.000000
# *INFO* f_current_datetime   : 2017-09 11:29:02
# *INFO* f_current_si         : 0.0300000000
# *INFO* f_current_price4pm   : 1
# *INFO* f_current_price4pmsi : 33.3333333333
# *INFO* f_1_step_time        : 11:29:03
# *INFO* f_1_step_si          : 0.0360000000
#      previous_pred_les_level  : 114.1709979419
#      previous_pred_les_trend  : -0.3858290021
#      f_1_step_pred_les_level  : 45.4957357591
#      f_1_step_pred_les_trend  : -0.4541184352
#      f_1_step_pred_les        : 45.0416173238
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 45.0416173238
#      f_1_step_pred_price_inc          : 1.6214982237
#      f_1_step_pred_price              : 90400.6214982237
#      f_1_step_pred_price_rounded      : 90400
#      f_1_step_pred_set_price_rounded  : 90700
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [90700]
# [90700]
#
# <<<< Record No.:  1955 >>>>
# 2017-09
# 11:29:03
# 90400
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:03
# in_current_price  : 90400.000000
# *INFO* f_current_datetime   : 2017-09 11:29:03
# *INFO* f_current_si         : 0.0360000000
# *INFO* f_current_price4pm   : 1
# *INFO* f_current_price4pmsi : 27.7777777778
# *INFO* f_1_step_time        : 11:29:04
# *INFO* f_1_step_si          : 0.0440000000
#      previous_pred_les_level  : 45.4957357591
#      previous_pred_les_trend  : -0.4541184352
#      f_1_step_pred_les_level  : 30.3876593596
#      f_1_step_pred_les_trend  : -0.4687723932
#      f_1_step_pred_les        : 29.9188869664
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 29.9188869664
#      f_1_step_pred_price_inc          : 1.3164310265
#      f_1_step_pred_price              : 90400.3164310265
#      f_1_step_pred_price_rounded      : 90400
#      f_1_step_pred_set_price_rounded  : 90700
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [90700]
# [90700]
#
# <<<< Record No.:  1956 >>>>
# 2017-09
# 11:29:04
# 90400
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:04
# in_current_price  : 90400.000000
# *INFO* f_current_datetime   : 2017-09 11:29:04
# *INFO* f_current_si         : 0.0440000000
# *INFO* f_current_price4pm   : 1
# *INFO* f_current_price4pmsi : 22.7272727273
# *INFO* f_1_step_time        : 11:29:05
# *INFO* f_1_step_si          : 0.0440000000
#      previous_pred_les_level  : 30.3876593596
#      previous_pred_les_trend  : -0.4687723932
#      f_1_step_pred_les_level  : 23.8144736072
#      f_1_step_pred_les_trend  : -0.4748768066
#      f_1_step_pred_les        : 23.3395968007
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 23.3395968007
#      f_1_step_pred_price_inc          : 1.0269422592
#      f_1_step_pred_price              : 90400.0269422592
#      f_1_step_pred_price_rounded      : 90400
#      f_1_step_pred_set_price_rounded  : 90700
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [90700]
# [90700]
#
# <<<< Record No.:  1957 >>>>
# 2017-09
# 11:29:05
# 90400
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:05
# in_current_price  : 90400.000000
# *INFO* f_current_datetime   : 2017-09 11:29:05
# *INFO* f_current_si         : 0.0440000000
# *INFO* f_current_price4pm   : 1
# *INFO* f_current_price4pmsi : 22.7272727273
# *INFO* f_1_step_time        : 11:29:06
# *INFO* f_1_step_si          : 0.0780000000
#      previous_pred_les_level  : 23.8144736072
#      previous_pred_les_trend  : -0.4748768066
#      f_1_step_pred_les_level  : 22.8198415511
#      f_1_step_pred_les_trend  : -0.4753965618
#      f_1_step_pred_les        : 22.3444449893
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 22.3444449893
#      f_1_step_pred_price_inc          : 1.7428667092
#      f_1_step_pred_price              : 90400.7428667092
#      f_1_step_pred_price_rounded      : 90400
#      f_1_step_pred_set_price_rounded  : 90700
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [90700]
# [90700]
#
# <<<< Record No.:  1958 >>>>
# 2017-09
# 11:29:06
# 90400
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:06
# in_current_price  : 90400.000000
# *INFO* f_current_datetime   : 2017-09 11:29:06
# *INFO* f_current_si         : 0.0780000000
# *INFO* f_current_price4pm   : 1
# *INFO* f_current_price4pmsi : 12.8205128205
# *INFO* f_1_step_time        : 11:29:07
# *INFO* f_1_step_si          : 0.0950000000
#      previous_pred_les_level  : 22.8198415511
#      previous_pred_les_trend  : -0.4753965618
#      f_1_step_pred_les_level  : 14.2603046517
#      f_1_step_pred_les_trend  : -0.4834807021
#      f_1_step_pred_les        : 13.7768239496
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 13.7768239496
#      f_1_step_pred_price_inc          : 1.3087982752
#      f_1_step_pred_price              : 90400.3087982752
#      f_1_step_pred_price_rounded      : 90400
#      f_1_step_pred_set_price_rounded  : 90700
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [90700]
# [90700]
#
# <<<< Record No.:  1959 >>>>
# 2017-09
# 11:29:07
# 90400
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:07
# in_current_price  : 90400.000000
# *INFO* f_current_datetime   : 2017-09 11:29:07
# *INFO* f_current_si         : 0.0950000000
# *INFO* f_current_price4pm   : 1
# *INFO* f_current_price4pmsi : 10.5263157895
# *INFO* f_1_step_time        : 11:29:08
# *INFO* f_1_step_si          : 0.1310000000
#      previous_pred_les_level  : 14.2603046517
#      previous_pred_les_trend  : -0.4834807021
#      f_1_step_pred_les_level  : 11.0177152465
#      f_1_step_pred_les_trend  : -0.4862398109
#      f_1_step_pred_les        : 10.5314754356
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 10.5314754356
#      f_1_step_pred_price_inc          : 1.3796232821
#      f_1_step_pred_price              : 90400.3796232821
#      f_1_step_pred_price_rounded      : 90400
#      f_1_step_pred_set_price_rounded  : 90700
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [90700]
# [90700]
# <<<< Record No.:  1960 >>>>
# 2017-09
# 11:29:08
# 90400
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:08
# in_current_price  : 90400.000000
# *INFO* f_current_datetime   : 2017-09 11:29:08
# *INFO* f_current_si         : 0.1310000000
# *INFO* f_current_price4pm   : 1
# *INFO* f_current_price4pmsi : 7.6335877863
# *INFO* f_1_step_time        : 11:29:09
# *INFO* f_1_step_si          : 0.1960000000
#      previous_pred_les_level  : 11.0177152465
#      previous_pred_les_trend  : -0.4862398109
#      f_1_step_pred_les_level  : 8.0716794160
#      f_1_step_pred_les_trend  : -0.4886996069
#      f_1_step_pred_les        : 7.5829798091
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 7.5829798091
#      f_1_step_pred_price_inc          : 1.4862640426
#      f_1_step_pred_price              : 90400.4862640426
#      f_1_step_pred_price_rounded      : 90400
#      f_1_step_pred_set_price_rounded  : 90700
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [90700]
# [90700]
#
# <<<< Record No.:  1961 >>>>
# 2017-09
# 11:29:09
# 90400
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:09
# in_current_price  : 90400.000000
# *INFO* f_current_datetime   : 2017-09 11:29:09
# *INFO* f_current_si         : 0.1960000000
# *INFO* f_current_price4pm   : 1
# *INFO* f_current_price4pmsi : 5.1020408163
# *INFO* f_1_step_time        : 11:29:10
# *INFO* f_1_step_si          : 0.2320000000
#      previous_pred_les_level  : 8.0716794160
#      previous_pred_les_trend  : -0.4886996069
#      f_1_step_pred_les_level  : 5.4770997345
#      f_1_step_pred_les_trend  : -0.4908054869
#      f_1_step_pred_les        : 4.9862942475
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 4.9862942475
#      f_1_step_pred_price_inc          : 1.1568202654
#      f_1_step_pred_price              : 90400.1568202654
#      f_1_step_pred_price_rounded      : 90400
#      f_1_step_pred_set_price_rounded  : 90700
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [90700]
# [90700]
#
# <<<< Record No.:  1962 >>>>
# 2017-09
# 11:29:10
# 90500
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:10
# in_current_price  : 90500.000000
# *INFO* f_current_datetime   : 2017-09 11:29:10
# *INFO* f_current_si         : 0.2320000000
# *INFO* f_current_price4pm   : 101
# *INFO* f_current_price4pmsi : 435.3448275862
# *INFO* f_1_step_time        : 11:29:11
# *INFO* f_1_step_si          : 0.2890000000
#      previous_pred_les_level  : 5.4770997345
#      previous_pred_les_trend  : -0.4908054869
#      f_1_step_pred_les_level  : 370.2848618271
#      f_1_step_pred_les_trend  : -0.1255069194
#      f_1_step_pred_les        : 370.1593549077
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 370.1593549077
#      f_1_step_pred_price_inc          : 106.9760535683
#      f_1_step_pred_price              : 90505.9760535683
#      f_1_step_pred_price_rounded      : 90500
#      f_1_step_pred_set_price_rounded  : 90800
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [90800]
# [90800]
#
# <<<< Record No.:  1963 >>>>
# 2017-09
# 11:29:11
# 90500
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:11
# in_current_price  : 90500.000000
# *INFO* f_current_datetime   : 2017-09 11:29:11
# *INFO* f_current_si         : 0.2890000000
# *INFO* f_current_price4pm   : 101
# *INFO* f_current_price4pmsi : 349.4809688581
# *INFO* f_1_step_time        : 11:29:12
# *INFO* f_1_step_si          : 0.3390000000
#      previous_pred_les_level  : 370.2848618271
#      previous_pred_les_trend  : -0.1255069194
#      f_1_step_pred_les_level  : 352.6070485896
#      f_1_step_pred_les_trend  : -0.1430592257
#      f_1_step_pred_les        : 352.4639893639
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 352.4639893639
#      f_1_step_pred_price_inc          : 119.4852923944
#      f_1_step_pred_price              : 90518.4852923944
#      f_1_step_pred_price_rounded      : 90500
#      f_1_step_pred_set_price_rounded  : 90800
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [90800]
# [90800]
#
# <<<< Record No.:  1964 >>>>
# 2017-09
# 11:29:12
# 90500
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:12
# in_current_price  : 90500.000000
# *INFO* f_current_datetime   : 2017-09 11:29:12
# *INFO* f_current_si         : 0.3390000000
# *INFO* f_current_price4pm   : 101
# *INFO* f_current_price4pmsi : 297.9351032448
# *INFO* f_1_step_time        : 11:29:13
# *INFO* f_1_step_si          : 0.3570000000
#      previous_pred_les_level  : 352.6070485896
#      previous_pred_les_trend  : -0.1430592257
#      f_1_step_pred_les_level  : 306.1785727917
#      f_1_step_pred_les_trend  : -0.1893446423
#      f_1_step_pred_les        : 305.9892281494
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 305.9892281494
#      f_1_step_pred_price_inc          : 109.2381544493
#      f_1_step_pred_price              : 90508.2381544493
#      f_1_step_pred_price_rounded      : 90500
#      f_1_step_pred_set_price_rounded  : 90800
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [90800]
# [90800]
#
# <<<< Record No.:  1965 >>>>
# 2017-09
# 11:29:13
# 90600
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:13
# in_current_price  : 90600.000000
# *INFO* f_current_datetime   : 2017-09 11:29:13
# *INFO* f_current_si         : 0.3570000000
# *INFO* f_current_price4pm   : 201
# *INFO* f_current_price4pmsi : 563.0252100840
# *INFO* f_1_step_time        : 11:29:14
# *INFO* f_1_step_si          : 0.3750000000
#      previous_pred_les_level  : 306.1785727917
#      previous_pred_les_trend  : -0.1893446423
#      f_1_step_pred_les_level  : 524.1674882357
#      f_1_step_pred_les_trend  : 0.0288336178
#      f_1_step_pred_les        : 524.1963218535
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 524.1963218535
#      f_1_step_pred_price_inc          : 196.5736206951
#      f_1_step_pred_price              : 90595.5736206951
#      f_1_step_pred_price_rounded      : 90600
#      f_1_step_pred_set_price_rounded  : 90900
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [90900]
# [90900]
#
# <<<< Record No.:  1966 >>>>
# 2017-09
# 11:29:14
# 90600
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:14
# in_current_price  : 90600.000000
# *INFO* f_current_datetime   : 2017-09 11:29:14
# *INFO* f_current_si         : 0.3750000000
# *INFO* f_current_price4pm   : 201
# *INFO* f_current_price4pmsi : 536.0000000000
# *INFO* f_1_step_time        : 11:29:15
# *INFO* f_1_step_si          : 0.4050000000
#      previous_pred_les_level  : 524.1674882357
#      previous_pred_les_trend  : 0.0288336178
#      f_1_step_pred_les_level  : 534.2155648452
#      f_1_step_pred_les_trend  : 0.0388528608
#      f_1_step_pred_les        : 534.2544177061
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 534.2544177061
#      f_1_step_pred_price_inc          : 216.3730391710
#      f_1_step_pred_price              : 90615.3730391710
#      f_1_step_pred_price_rounded      : 90600
#      f_1_step_pred_set_price_rounded  : 90900
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [90900]
# [90900]
#
# <<<< Record No.:  1967 >>>>
# 2017-09
# 11:29:15
# 90600
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:15
# in_current_price  : 90600.000000
# *INFO* f_current_datetime   : 2017-09 11:29:15
# *INFO* f_current_si         : 0.4050000000
# *INFO* f_current_price4pm   : 201
# *INFO* f_current_price4pmsi : 496.2962962963
# *INFO* f_1_step_time        : 11:29:16
# *INFO* f_1_step_si          : 0.4250000000
#      previous_pred_les_level  : 534.2155648452
#      previous_pred_les_trend  : 0.0388528608
#      f_1_step_pred_les_level  : 502.0346606783
#      f_1_step_pred_les_trend  : 0.0066331038
#      f_1_step_pred_les        : 502.0412937821
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 502.0412937821
#      f_1_step_pred_price_inc          : 213.3675498574
#      f_1_step_pred_price              : 90612.3675498574
#      f_1_step_pred_price_rounded      : 90600
#      f_1_step_pred_set_price_rounded  : 90900
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [90900]
# [90900]
#
# <<<< Record No.:  1968 >>>>
# 2017-09
# 11:29:16
# 90700
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:16
# in_current_price  : 90700.000000
# *INFO* f_current_datetime   : 2017-09 11:29:16
# *INFO* f_current_si         : 0.4250000000
# *INFO* f_current_price4pm   : 301
# *INFO* f_current_price4pmsi : 708.2352941176
# *INFO* f_1_step_time        : 11:29:17
# *INFO* f_1_step_si          : 0.4640000000
#      previous_pred_les_level  : 502.0346606783
#      previous_pred_les_trend  : 0.0066331038
#      f_1_step_pred_les_level  : 677.0636696177
#      f_1_step_pred_les_trend  : 0.1816554796
#      f_1_step_pred_les        : 677.2453250974
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 677.2453250974
#      f_1_step_pred_price_inc          : 314.2418308452
#      f_1_step_pred_price              : 90713.2418308452
#      f_1_step_pred_price_rounded      : 90700
#      f_1_step_pred_set_price_rounded  : 91000
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91000]
# [91000]
#
# <<<< Record No.:  1969 >>>>
# 2017-09
# 11:29:17
# 90700
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:17
# in_current_price  : 90700.000000
# *INFO* f_current_datetime   : 2017-09 11:29:17
# *INFO* f_current_si         : 0.4640000000
# *INFO* f_current_price4pm   : 301
# *INFO* f_current_price4pmsi : 648.7068965517
# *INFO* f_1_step_time        : 11:29:18
# *INFO* f_1_step_si          : 0.4930000000
#      previous_pred_les_level  : 677.0636696177
#      previous_pred_les_trend  : 0.1816554796
#      f_1_step_pred_les_level  : 653.0212276040
#      f_1_step_pred_les_trend  : 0.1574313821
#      f_1_step_pred_les        : 653.1786589861
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 653.1786589861
#      f_1_step_pred_price_inc          : 322.0170788802
#      f_1_step_pred_price              : 90721.0170788802
#      f_1_step_pred_price_rounded      : 90700
#      f_1_step_pred_set_price_rounded  : 91000
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91000]
# [91000]
#
# <<<< Record No.:  1970 >>>>
# 2017-09
# 11:29:18
# 90700
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:18
# in_current_price  : 90700.000000
# *INFO* f_current_datetime   : 2017-09 11:29:18
# *INFO* f_current_si         : 0.4930000000
# *INFO* f_current_price4pm   : 301
# *INFO* f_current_price4pmsi : 610.5476673428
# *INFO* f_1_step_time        : 11:29:19
# *INFO* f_1_step_si          : 0.5120000000
#      previous_pred_les_level  : 653.0212276040
#      previous_pred_les_trend  : 0.1574313821
#      f_1_step_pred_les_level  : 616.9924584686
#      f_1_step_pred_les_trend  : 0.1212451816
#      f_1_step_pred_les        : 617.1137036503
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 617.1137036503
#      f_1_step_pred_price_inc          : 315.9622162689
#      f_1_step_pred_price              : 90714.9622162689
#      f_1_step_pred_price_rounded      : 90700
#      f_1_step_pred_set_price_rounded  : 91000
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91000]
# [91000]
#
# <<<< Record No.:  1971 >>>>
# 2017-09
# 11:29:19
# 90700
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:19
# in_current_price  : 90700.000000
# *INFO* f_current_datetime   : 2017-09 11:29:19
# *INFO* f_current_si         : 0.5120000000
# *INFO* f_current_price4pm   : 301
# *INFO* f_current_price4pmsi : 587.8906250000
# *INFO* f_1_step_time        : 11:29:20
# *INFO* f_1_step_si          : 0.5340000000
#      previous_pred_les_level  : 616.9924584686
#      previous_pred_les_trend  : 0.1212451816
#      f_1_step_pred_les_level  : 592.3084588503
#      f_1_step_pred_les_trend  : 0.0964399368
#      f_1_step_pred_les        : 592.4048987871
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 592.4048987871
#      f_1_step_pred_price_inc          : 316.3442159523
#      f_1_step_pred_price              : 90715.3442159523
#      f_1_step_pred_price_rounded      : 90700
#      f_1_step_pred_set_price_rounded  : 91000
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91000]
# [91000]
#
# <<<< Record No.:  1972 >>>>
# 2017-09
# 11:29:20
# 90700
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:20
# in_current_price  : 90700.000000
# *INFO* f_current_datetime   : 2017-09 11:29:20
# *INFO* f_current_si         : 0.5340000000
# *INFO* f_current_price4pm   : 301
# *INFO* f_current_price4pmsi : 563.6704119850
# *INFO* f_1_step_time        : 11:29:21
# *INFO* f_1_step_si          : 0.5710000000
#      previous_pred_les_level  : 592.3084588503
#      previous_pred_les_trend  : 0.0964399368
#      f_1_step_pred_les_level  : 568.0143823786
#      f_1_step_pred_les_trend  : 0.0720494204
#      f_1_step_pred_les        : 568.0864317990
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 568.0864317990
#      f_1_step_pred_price_inc          : 324.3773525572
#      f_1_step_pred_price              : 90723.3773525572
#      f_1_step_pred_price_rounded      : 90700
#      f_1_step_pred_set_price_rounded  : 91000
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91000]
# [91000]
#
# <<<< Record No.:  1973 >>>>
# 2017-09
# 11:29:21
# 90700
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:21
# in_current_price  : 90700.000000
# *INFO* f_current_datetime   : 2017-09 11:29:21
# *INFO* f_current_si         : 0.5710000000
# *INFO* f_current_price4pm   : 301
# *INFO* f_current_price4pmsi : 527.1453590193
# *INFO* f_1_step_time        : 11:29:22
# *INFO* f_1_step_si          : 0.5820000000
#      previous_pred_les_level  : 568.0143823786
#      previous_pred_les_trend  : 0.0720494204
#      f_1_step_pred_les_level  : 533.3346746407
#      f_1_step_pred_les_trend  : 0.0372976633
#      f_1_step_pred_les        : 533.3719723039
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 533.3719723039
#      f_1_step_pred_price_inc          : 310.4224878809
#      f_1_step_pred_price              : 90709.4224878809
#      f_1_step_pred_price_rounded      : 90700
#      f_1_step_pred_set_price_rounded  : 91000
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91000]
# [91000]
#
# <<<< Record No.:  1974 >>>>
# 2017-09
# 11:29:22
# 90700
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:22
# in_current_price  : 90700.000000
# *INFO* f_current_datetime   : 2017-09 11:29:22
# *INFO* f_current_si         : 0.5820000000
# *INFO* f_current_price4pm   : 301
# *INFO* f_current_price4pmsi : 517.1821305842
# *INFO* f_1_step_time        : 11:29:23
# *INFO* f_1_step_si          : 0.5930000000
#      previous_pred_les_level  : 533.3346746407
#      previous_pred_les_trend  : 0.0372976633
#      f_1_step_pred_les_level  : 519.6296492607
#      f_1_step_pred_les_trend  : 0.0235553402
#      f_1_step_pred_les        : 519.6532046009
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 519.6532046009
#      f_1_step_pred_price_inc          : 308.1543503283
#      f_1_step_pred_price              : 90707.1543503283
#      f_1_step_pred_price_rounded      : 90700
#      f_1_step_pred_set_price_rounded  : 91000
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91000]
# [91000]
#
# <<<< Record No.:  1975 >>>>
# 2017-09
# 11:29:23
# 90700
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:23
# in_current_price  : 90700.000000
# *INFO* f_current_datetime   : 2017-09 11:29:23
# *INFO* f_current_si         : 0.5930000000
# *INFO* f_current_price4pm   : 301
# *INFO* f_current_price4pmsi : 507.5885328836
# *INFO* f_1_step_time        : 11:29:24
# *INFO* f_1_step_si          : 0.6210000000
#      previous_pred_les_level  : 519.6296492607
#      previous_pred_les_trend  : 0.0235553402
#      f_1_step_pred_les_level  : 509.4124240535
#      f_1_step_pred_les_trend  : 0.0133145597
#      f_1_step_pred_les        : 509.4257386131
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 509.4257386131
#      f_1_step_pred_price_inc          : 316.3533836788
#      f_1_step_pred_price              : 90715.3533836788
#      f_1_step_pred_price_rounded      : 90700
#      f_1_step_pred_set_price_rounded  : 91000
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91000]
# [91000]
#
# <<<< Record No.:  1976 >>>>
# 2017-09
# 11:29:24
# 90700
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:24
# in_current_price  : 90700.000000
# *INFO* f_current_datetime   : 2017-09 11:29:24
# *INFO* f_current_si         : 0.6210000000
# *INFO* f_current_price4pm   : 301
# *INFO* f_current_price4pmsi : 484.7020933977
# *INFO* f_1_step_time        : 11:29:25
# *INFO* f_1_step_si          : 0.6610000000
#      previous_pred_les_level  : 509.4124240535
#      previous_pred_les_trend  : 0.0133145597
#      f_1_step_pred_les_level  : 488.4397200196
#      f_1_step_pred_les_trend  : -0.0076714589
#      f_1_step_pred_les        : 488.4320485607
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 488.4320485607
#      f_1_step_pred_price_inc          : 322.8535840986
#      f_1_step_pred_price              : 90721.8535840986
#      f_1_step_pred_price_rounded      : 90700
#      f_1_step_pred_set_price_rounded  : 91000
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91000]
# [91000]
#
# <<<< Record No.:  1977 >>>>
# 2017-09
# 11:29:25
# 90700
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:25
# in_current_price  : 90700.000000
# *INFO* f_current_datetime   : 2017-09 11:29:25
# *INFO* f_current_si         : 0.6610000000
# *INFO* f_current_price4pm   : 301
# *INFO* f_current_price4pmsi : 455.3706505295
# *INFO* f_1_step_time        : 11:29:26
# *INFO* f_1_step_si          : 0.6770000000
#      previous_pred_les_level  : 488.4397200196
#      previous_pred_les_trend  : -0.0076714589
#      f_1_step_pred_les_level  : 460.3687469008
#      f_1_step_pred_les_trend  : -0.0357347606
#      f_1_step_pred_les        : 460.3330121403
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 460.3330121403
#      f_1_step_pred_price_inc          : 311.6454492190
#      f_1_step_pred_price              : 90710.6454492190
#      f_1_step_pred_price_rounded      : 90700
#      f_1_step_pred_set_price_rounded  : 91000
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91000]
# [91000]
#
# <<<< Record No.:  1978 >>>>
# 2017-09
# 11:29:26
# 90700
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:26
# in_current_price  : 90700.000000
# *INFO* f_current_datetime   : 2017-09 11:29:26
# *INFO* f_current_si         : 0.6770000000
# *INFO* f_current_price4pm   : 301
# *INFO* f_current_price4pmsi : 444.6085672083
# *INFO* f_1_step_time        : 11:29:27
# *INFO* f_1_step_si          : 0.6970000000
#      previous_pred_les_level  : 460.3687469008
#      previous_pred_les_trend  : -0.0357347606
#      f_1_step_pred_les_level  : 446.9857289690
#      f_1_step_pred_les_trend  : -0.0490820438
#      f_1_step_pred_les        : 446.9366469252
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 446.9366469252
#      f_1_step_pred_price_inc          : 311.5148429069
#      f_1_step_pred_price              : 90710.5148429069
#      f_1_step_pred_price_rounded      : 90700
#      f_1_step_pred_set_price_rounded  : 91000
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91000]
# [91000]
#
# <<<< Record No.:  1979 >>>>
# 2017-09
# 11:29:27
# 90700
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:27
# in_current_price  : 90700.000000
# *INFO* f_current_datetime   : 2017-09 11:29:27
# *INFO* f_current_si         : 0.6970000000
# *INFO* f_current_price4pm   : 301
# *INFO* f_current_price4pmsi : 431.8507890961
# *INFO* f_1_step_time        : 11:29:28
# *INFO* f_1_step_si          : 0.7200000000
#      previous_pred_les_level  : 446.9857289690
#      previous_pred_les_trend  : -0.0490820438
#      f_1_step_pred_les_level  : 434.1314116882
#      f_1_step_pred_les_trend  : -0.0618872790
#      f_1_step_pred_les        : 434.0695244092
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 434.0695244092
#      f_1_step_pred_price_inc          : 312.5300575746
#      f_1_step_pred_price              : 90711.5300575746
#      f_1_step_pred_price_rounded      : 90700
#      f_1_step_pred_set_price_rounded  : 91000
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91000]
# [91000]
#
# <<<< Record No.:  1980 >>>>
# 2017-09
# 11:29:28
# 90700
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:28
# in_current_price  : 90700.000000
# *INFO* f_current_datetime   : 2017-09 11:29:28
# *INFO* f_current_si         : 0.7200000000
# *INFO* f_current_price4pm   : 301
# *INFO* f_current_price4pmsi : 418.0555555556
# *INFO* f_1_step_time        : 11:29:29
# *INFO* f_1_step_si          : 0.7340000000
#      previous_pred_les_level  : 434.1314116882
#      previous_pred_les_trend  : -0.0618872790
#      f_1_step_pred_les_level  : 420.4764864413
#      f_1_step_pred_les_trend  : -0.0754803170
#      f_1_step_pred_les        : 420.4010061243
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 420.4010061243
#      f_1_step_pred_price_inc          : 308.5743384952
#      f_1_step_pred_price              : 90707.5743384952
#      f_1_step_pred_price_rounded      : 90700
#      f_1_step_pred_set_price_rounded  : 91000
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91000]
# [91000]
#
# <<<< Record No.:  1981 >>>>
# 2017-09
# 11:29:29
# 90700
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:29
# in_current_price  : 90700.000000
# *INFO* f_current_datetime   : 2017-09 11:29:29
# *INFO* f_current_si         : 0.7340000000
# *INFO* f_current_price4pm   : 301
# *INFO* f_current_price4pmsi : 410.0817438692
# *INFO* f_1_step_time        : 11:29:30
# *INFO* f_1_step_si          : 0.7760000000
#      previous_pred_les_level  : 420.4764864413
#      previous_pred_les_trend  : -0.0754803170
#      f_1_step_pred_les_level  : 411.6417706770
#      f_1_step_pred_les_trend  : -0.0842395524
#      f_1_step_pred_les        : 411.5575311246
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 411.5575311246
#      f_1_step_pred_price_inc          : 319.3686441527
#      f_1_step_pred_price              : 90718.3686441527
#      f_1_step_pred_price_rounded      : 90700
#      f_1_step_pred_set_price_rounded  : 91000
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91000]
# [91000]
#
# <<<< Record No.:  1982 >>>>
# 2017-09
# 11:29:30
# 90700
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:30
# in_current_price  : 90700.000000
# *INFO* f_current_datetime   : 2017-09 11:29:30
# *INFO* f_current_si         : 0.7760000000
# *INFO* f_current_price4pm   : 301
# *INFO* f_current_price4pmsi : 387.8865979381
# *INFO* f_1_step_time        : 11:29:31
# *INFO* f_1_step_si          : 0.7880000000
#      previous_pred_les_level  : 411.6417706770
#      previous_pred_les_trend  : -0.0842395524
#      f_1_step_pred_les_level  : 391.4650795605
#      f_1_step_pred_les_trend  : -0.1043320040
#      f_1_step_pred_les        : 391.3607475566
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 391.3607475566
#      f_1_step_pred_price_inc          : 308.3922690746
#      f_1_step_pred_price              : 90707.3922690746
#      f_1_step_pred_price_rounded      : 90700
#      f_1_step_pred_set_price_rounded  : 91000
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91000]
# [91000]
#
# <<<< Record No.:  1983 >>>>
# 2017-09
# 11:29:31
# 90700
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:31
# in_current_price  : 90700.000000
# *INFO* f_current_datetime   : 2017-09 11:29:31
# *INFO* f_current_si         : 0.7880000000
# *INFO* f_current_price4pm   : 301
# *INFO* f_current_price4pmsi : 381.9796954315
# *INFO* f_1_step_time        : 11:29:32
# *INFO* f_1_step_si          : 0.8130000000
#      previous_pred_les_level  : 391.4650795605
#      previous_pred_les_trend  : -0.1043320040
#      f_1_step_pred_les_level  : 383.3978872013
#      f_1_step_pred_les_trend  : -0.1122948643
#      f_1_step_pred_les        : 383.2855923369
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 383.2855923369
#      f_1_step_pred_price_inc          : 311.6111865699
#      f_1_step_pred_price              : 90710.6111865699
#      f_1_step_pred_price_rounded      : 90700
#      f_1_step_pred_set_price_rounded  : 91000
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91000]
# [91000]
#
# <<<< Record No.:  1984 >>>>
# 2017-09
# 11:29:32
# 90700
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:32
# in_current_price  : 90700.000000
# *INFO* f_current_datetime   : 2017-09 11:29:32
# *INFO* f_current_si         : 0.8130000000
# *INFO* f_current_price4pm   : 301
# *INFO* f_current_price4pmsi : 370.2337023370
# *INFO* f_1_step_time        : 11:29:33
# *INFO* f_1_step_si          : 0.8320000000
#      previous_pred_les_level  : 383.3978872013
#      previous_pred_les_trend  : -0.1122948643
#      f_1_step_pred_les_level  : 372.2068374109
#      f_1_step_pred_les_trend  : -0.1233736193
#      f_1_step_pred_les        : 372.0834637917
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 372.0834637917
#      f_1_step_pred_price_inc          : 309.5734418747
#      f_1_step_pred_price              : 90708.5734418747
#      f_1_step_pred_price_rounded      : 90700
#      f_1_step_pred_set_price_rounded  : 91000
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91000]
# [91000]
#
# <<<< Record No.:  1985 >>>>
# 2017-09
# 11:29:33
# 90700
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:33
# in_current_price  : 90700.000000
# *INFO* f_current_datetime   : 2017-09 11:29:33
# *INFO* f_current_si         : 0.8320000000
# *INFO* f_current_price4pm   : 301
# *INFO* f_current_price4pmsi : 361.7788461538
# *INFO* f_1_step_time        : 11:29:34
# *INFO* f_1_step_si          : 0.8620000000
#      previous_pred_les_level  : 372.2068374109
#      previous_pred_les_trend  : -0.1233736193
#      f_1_step_pred_les_level  : 363.3366590441
#      f_1_step_pred_les_trend  : -0.1321204240
#      f_1_step_pred_les        : 363.2045386201
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 363.2045386201
#      f_1_step_pred_price_inc          : 313.0823122905
#      f_1_step_pred_price              : 90712.0823122905
#      f_1_step_pred_price_rounded      : 90700
#      f_1_step_pred_set_price_rounded  : 91000
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91000]
# [91000]
#
# <<<< Record No.:  1986 >>>>
# 2017-09
# 11:29:34
# 90700
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:34
# in_current_price  : 90700.000000
# *INFO* f_current_datetime   : 2017-09 11:29:34
# *INFO* f_current_si         : 0.8620000000
# *INFO* f_current_price4pm   : 301
# *INFO* f_current_price4pmsi : 349.1879350348
# *INFO* f_1_step_time        : 11:29:35
# *INFO* f_1_step_si          : 0.9190000000
#      previous_pred_les_level  : 363.3366590441
#      previous_pred_les_trend  : -0.1321204240
#      f_1_step_pred_les_level  : 351.3069118383
#      f_1_step_pred_les_trend  : -0.1440180508
#      f_1_step_pred_les        : 351.1628937875
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 351.1628937875
#      f_1_step_pred_price_inc          : 322.7186993907
#      f_1_step_pred_price              : 90721.7186993907
#      f_1_step_pred_price_rounded      : 90700
#      f_1_step_pred_set_price_rounded  : 91000
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91000]
# [91000]
#
# <<<< Record No.:  1987 >>>>
# 2017-09
# 11:29:35
# 90800
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:35
# in_current_price  : 90800.000000
# *INFO* f_current_datetime   : 2017-09 11:29:35
# *INFO* f_current_si         : 0.9190000000
# *INFO* f_current_price4pm   : 401
# *INFO* f_current_price4pmsi : 436.3438520131
# *INFO* f_1_step_time        : 11:29:36
# *INFO* f_1_step_si          : 0.9490000000
#      previous_pred_les_level  : 351.3069118383
#      previous_pred_les_trend  : -0.1440180508
#      f_1_step_pred_les_level  : 423.4665188218
#      f_1_step_pred_les_trend  : -0.0717144258
#      f_1_step_pred_les        : 423.3948043961
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 423.3948043961
#      f_1_step_pred_price_inc          : 401.8016693719
#      f_1_step_pred_price              : 90800.8016693719
#      f_1_step_pred_price_rounded      : 90800
#      f_1_step_pred_set_price_rounded  : 91100
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91100]
# [91100]
#
# <<<< Record No.:  1988 >>>>
# 2017-09
# 11:29:36
# 90800
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:36
# in_current_price  : 90800.000000
# *INFO* f_current_datetime   : 2017-09 11:29:36
# *INFO* f_current_si         : 0.9490000000
# *INFO* f_current_price4pm   : 401
# *INFO* f_current_price4pmsi : 422.5500526870
# *INFO* f_1_step_time        : 11:29:37
# *INFO* f_1_step_si          : 0.9780000000
#      previous_pred_les_level  : 423.4665188218
#      previous_pred_les_trend  : -0.0717144258
#      f_1_step_pred_les_level  : 422.6777590365
#      f_1_step_pred_les_trend  : -0.0724314711
#      f_1_step_pred_les        : 422.6053275654
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 422.6053275654
#      f_1_step_pred_price_inc          : 413.3080103590
#      f_1_step_pred_price              : 90812.3080103590
#      f_1_step_pred_price_rounded      : 90800
#      f_1_step_pred_set_price_rounded  : 91100
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91100]
# [91100]
#
# <<<< Record No.:  1989 >>>>
# 2017-09
# 11:29:37
# 90900
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:37
# in_current_price  : 90900.000000
# *INFO* f_current_datetime   : 2017-09 11:29:37
# *INFO* f_current_si         : 0.9780000000
# *INFO* f_current_price4pm   : 501
# *INFO* f_current_price4pmsi : 512.2699386503
# *INFO* f_1_step_time        : 11:29:38
# *INFO* f_1_step_si          : 0.9990000000
#      previous_pred_les_level  : 422.6777590365
#      previous_pred_les_trend  : -0.0724314711
#      f_1_step_pred_les_level  : 498.7147838780
#      f_1_step_pred_les_trend  : 0.0036779852
#      f_1_step_pred_les        : 498.7184618632
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 498.7184618632
#      f_1_step_pred_price_inc          : 498.2197434013
#      f_1_step_pred_price              : 90897.2197434013
#      f_1_step_pred_price_rounded      : 90900
#      f_1_step_pred_set_price_rounded  : 91200
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91200]
# [91200]
#
# <<<< Record No.:  1990 >>>>
# 2017-09
# 11:29:38
# 91000
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:38
# in_current_price  : 91000.000000
# *INFO* f_current_datetime   : 2017-09 11:29:38
# *INFO* f_current_si         : 0.9990000000
# *INFO* f_current_price4pm   : 601
# *INFO* f_current_price4pmsi : 601.6016016016
# *INFO* f_1_step_time        : 11:29:39
# *INFO* f_1_step_si          : 1.0350000000
#      previous_pred_les_level  : 498.7147838780
#      previous_pred_les_trend  : 0.0036779852
#      f_1_step_pred_les_level  : 586.0481199577
#      f_1_step_pred_les_trend  : 0.0910076433
#      f_1_step_pred_les        : 586.1391276010
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 586.1391276010
#      f_1_step_pred_price_inc          : 606.6539970670
#      f_1_step_pred_price              : 91005.6539970670
#      f_1_step_pred_price_rounded      : 91000
#      f_1_step_pred_set_price_rounded  : 91300
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91300]
# [91300]
#
# <<<< Record No.:  1991 >>>>
# 2017-09
# 11:29:39
# 91000
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:39
# in_current_price  : 91000.000000
# *INFO* f_current_datetime   : 2017-09 11:29:39
# *INFO* f_current_si         : 1.0350000000
# *INFO* f_current_price4pm   : 601
# *INFO* f_current_price4pmsi : 580.6763285024
# *INFO* f_1_step_time        : 11:29:40
# *INFO* f_1_step_si          : 1.0760000000
#      previous_pred_les_level  : 586.0481199577
#      previous_pred_les_trend  : 0.0910076433
#      f_1_step_pred_les_level  : 581.5021736868
#      f_1_step_pred_les_trend  : 0.0863706894
#      f_1_step_pred_les        : 581.5885443761
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 581.5885443761
#      f_1_step_pred_price_inc          : 625.7892737487
#      f_1_step_pred_price              : 91024.7892737487
#      f_1_step_pred_price_rounded      : 91000
#      f_1_step_pred_set_price_rounded  : 91300
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91300]
# [91300]
#
# <<<< Record No.:  1992 >>>>
# 2017-09
# 11:29:40
# 91000
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:40
# in_current_price  : 91000.000000
# *INFO* f_current_datetime   : 2017-09 11:29:40
# *INFO* f_current_si         : 1.0760000000
# *INFO* f_current_price4pm   : 601
# *INFO* f_current_price4pmsi : 558.5501858736
# *INFO* f_1_step_time        : 11:29:41
# *INFO* f_1_step_si          : 1.1100000000
#      previous_pred_les_level  : 581.5021736868
#      previous_pred_les_trend  : 0.0863706894
#      f_1_step_pred_les_level  : 562.0330372619
#      f_1_step_pred_les_trend  : 0.0668151823
#      f_1_step_pred_les        : 562.0998524442
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 562.0998524442
#      f_1_step_pred_price_inc          : 623.9308362131
#      f_1_step_pred_price              : 91022.9308362131
#      f_1_step_pred_price_rounded      : 91000
#      f_1_step_pred_set_price_rounded  : 91300
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91300]
# [91300]
#
# <<<< Record No.:  1993 >>>>
# 2017-09
# 11:29:41
# 91000
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:41
# in_current_price  : 91000.000000
# *INFO* f_current_datetime   : 2017-09 11:29:41
# *INFO* f_current_si         : 1.1100000000
# *INFO* f_current_price4pm   : 601
# *INFO* f_current_price4pmsi : 541.4414414414
# *INFO* f_1_step_time        : 11:29:42
# *INFO* f_1_step_si          : 1.1650000000
#      previous_pred_les_level  : 562.0330372619
#      previous_pred_les_trend  : 0.0668151823
#      f_1_step_pred_les_level  : 544.5645014213
#      f_1_step_pred_les_trend  : 0.0492798312
#      f_1_step_pred_les        : 544.6137812526
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 544.6137812526
#      f_1_step_pred_price_inc          : 634.4750551593
#      f_1_step_pred_price              : 91033.4750551593
#      f_1_step_pred_price_rounded      : 91000
#      f_1_step_pred_set_price_rounded  : 91300
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91300]
# [91300]
#
# <<<< Record No.:  1994 >>>>
# 2017-09
# 11:29:42
# 91000
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:42
# in_current_price  : 91000.000000
# *INFO* f_current_datetime   : 2017-09 11:29:42
# *INFO* f_current_si         : 1.1650000000
# *INFO* f_current_price4pm   : 601
# *INFO* f_current_price4pmsi : 515.8798283262
# *INFO* f_1_step_time        : 11:29:43
# *INFO* f_1_step_si          : 1.2760000000
#      previous_pred_les_level  : 544.5645014213
#      previous_pred_les_trend  : 0.0492798312
#      f_1_step_pred_les_level  : 520.2237180105
#      f_1_step_pred_les_trend  : 0.0248897680
#      f_1_step_pred_les        : 520.2486077785
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 520.2486077785
#      f_1_step_pred_price_inc          : 663.8372235253
#      f_1_step_pred_price              : 91062.8372235253
#      f_1_step_pred_price_rounded      : 91100
#      f_1_step_pred_set_price_rounded  : 91400
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91400]
# [91400]
#
# <<<< Record No.:  1995 >>>>
# 2017-09
# 11:29:43
# 91000
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:43
# in_current_price  : 91000.000000
# *INFO* f_current_datetime   : 2017-09 11:29:43
# *INFO* f_current_si         : 1.2760000000
# *INFO* f_current_price4pm   : 601
# *INFO* f_current_price4pmsi : 471.0031347962
# *INFO* f_1_step_time        : 11:29:44
# *INFO* f_1_step_si          : 1.3890000000
#      previous_pred_les_level  : 520.2237180105
#      previous_pred_les_trend  : 0.0248897680
#      f_1_step_pred_les_level  : 478.4478780459
#      f_1_step_pred_les_trend  : -0.0169109617
#      f_1_step_pred_les        : 478.4309670842
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 478.4309670842
#      f_1_step_pred_price_inc          : 664.5406132799
#      f_1_step_pred_price              : 91063.5406132799
#      f_1_step_pred_price_rounded      : 91100
#      f_1_step_pred_set_price_rounded  : 91400
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91400]
# [91400]
#
# <<<< Record No.:  1996 >>>>
# 2017-09
# 11:29:44
# 91100
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:44
# in_current_price  : 91100.000000
# *INFO* f_current_datetime   : 2017-09 11:29:44
# *INFO* f_current_si         : 1.3890000000
# *INFO* f_current_price4pm   : 701
# *INFO* f_current_price4pmsi : 504.6796256299
# *INFO* f_1_step_time        : 11:29:45
# *INFO* f_1_step_si          : 1.4450000000
#      previous_pred_les_level  : 478.4478780459
#      previous_pred_les_trend  : -0.0169109617
#      f_1_step_pred_les_level  : 500.7114532948
#      f_1_step_pred_les_trend  : 0.0053695245
#      f_1_step_pred_les        : 500.7168228192
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 500.7168228192
#      f_1_step_pred_price_inc          : 723.5358089738
#      f_1_step_pred_price              : 91122.5358089738
#      f_1_step_pred_price_rounded      : 91100
#      f_1_step_pred_set_price_rounded  : 91400
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91400]
# [91400]
#
# <<<< Record No.:  1997 >>>>
# 2017-09
# 11:29:45
# 91100
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:45
# in_current_price  : 91100.000000
# *INFO* f_current_datetime   : 2017-09 11:29:45
# *INFO* f_current_si         : 1.4450000000
# *INFO* f_current_price4pm   : 701
# *INFO* f_current_price4pmsi : 485.1211072664
# *INFO* f_1_step_time        : 11:29:46
# *INFO* f_1_step_si          : 1.5730000000
#      previous_pred_les_level  : 500.7114532948
#      previous_pred_les_trend  : 0.0053695245
#      f_1_step_pred_les_level  : 487.4788082094
#      f_1_step_pred_les_trend  : -0.0078684901
#      f_1_step_pred_les        : 487.4709397192
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 487.4709397192
#      f_1_step_pred_price_inc          : 766.7917881784
#      f_1_step_pred_price              : 91165.7917881784
#      f_1_step_pred_price_rounded      : 91200
#      f_1_step_pred_set_price_rounded  : 91500
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91500]
# [91500]
#
# <<<< Record No.:  1998 >>>>
# 2017-09
# 11:29:46
# 91200
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:46
# in_current_price  : 91200.000000
# *INFO* f_current_datetime   : 2017-09 11:29:46
# *INFO* f_current_si         : 1.5730000000
# *INFO* f_current_price4pm   : 801
# *INFO* f_current_price4pmsi : 509.2180546726
# *INFO* f_1_step_time        : 11:29:47
# *INFO* f_1_step_si          : 1.6460000000
#      previous_pred_les_level  : 487.4788082094
#      previous_pred_les_trend  : -0.0078684901
#      f_1_step_pred_les_level  : 505.9304085715
#      f_1_step_pred_les_trend  : 0.0105909787
#      f_1_step_pred_les        : 505.9409995502
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 505.9409995502
#      f_1_step_pred_price_inc          : 832.7788852596
#      f_1_step_pred_price              : 91231.7788852596
#      f_1_step_pred_price_rounded      : 91200
#      f_1_step_pred_set_price_rounded  : 91500
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91500]
# [91500]
#
# <<<< Record No.:  1999 >>>>
# 2017-09
# 11:29:47
# 91300
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:47
# in_current_price  : 91300.000000
# *INFO* f_current_datetime   : 2017-09 11:29:47
# *INFO* f_current_si         : 1.6460000000
# *INFO* f_current_price4pm   : 901
# *INFO* f_current_price4pmsi : 547.3876063183
# *INFO* f_1_step_time        : 11:29:48
# *INFO* f_1_step_si          : 1.7520000000
#      previous_pred_les_level  : 505.9304085715
#      previous_pred_les_trend  : 0.0105909787
#      f_1_step_pred_les_level  : 541.1218659919
#      f_1_step_pred_les_trend  : 0.0457718452
#      f_1_step_pred_les        : 541.1676378371
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 541.1676378371
#      f_1_step_pred_price_inc          : 948.1257014905
#      f_1_step_pred_price              : 91347.1257014905
#      f_1_step_pred_price_rounded      : 91300
#      f_1_step_pred_set_price_rounded  : 91600
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91600]
# [91600]
#
# <<<< Record No.:  2000 >>>>
# 2017-09
# 11:29:48
# 91400
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:48
# in_current_price  : 91400.000000
# *INFO* f_current_datetime   : 2017-09 11:29:48
# *INFO* f_current_si         : 1.7520000000
# *INFO* f_current_price4pm   : 1001
# *INFO* f_current_price4pmsi : 571.3470319635
# *INFO* f_1_step_time        : 11:29:49
# *INFO* f_1_step_si          : 1.7890000000
#      previous_pred_les_level  : 541.1218659919
#      previous_pred_les_trend  : 0.0457718452
#      f_1_step_pred_les_level  : 566.7846259778
#      f_1_step_pred_les_trend  : 0.0713888333
#      f_1_step_pred_les        : 566.8560148111
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 566.8560148111
#      f_1_step_pred_price_inc          : 1014.1054104970
#      f_1_step_pred_price              : 91413.1054104970
#      f_1_step_pred_price_rounded      : 91400
#      f_1_step_pred_set_price_rounded  : 91700
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91700]
# [91700]
#
# <<<< Record No.:  2001 >>>>
# 2017-09
# 11:29:49
# 91400
# ==>> Forecasting   1 out of next   1 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:49
# in_current_price  : 91400.000000
# *INFO* f_current_datetime   : 2017-09 11:29:49
# *INFO* f_current_si         : 1.7890000000
# *INFO* f_current_price4pm   : 1001
# *INFO* f_current_price4pmsi : 559.5304639463
# *INFO* f_1_step_time        : 11:29:50
# *INFO* f_1_step_si          : 1.9280000000
#      previous_pred_les_level  : 566.7846259778
#      previous_pred_les_trend  : 0.0713888333
#      f_1_step_pred_les_level  : 560.6379128558
#      f_1_step_pred_les_trend  : 0.0651707313
#      f_1_step_pred_les        : 560.7030835872
#      f_1_step_pred_adj_misc   : 0.0000000000
#      pred_les + pred_adj_misc : 560.7030835872
#      f_1_step_pred_price_inc          : 1081.0355451560
#      f_1_step_pred_price              : 91480.0355451560
#      f_1_step_pred_price_rounded      : 91500
#      f_1_step_pred_set_price_rounded  : 91800
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91800]
# [91800]

# %%
# Upon receiving 11:29:50 second price, to predict till 11:30:00 <- ten-step forward price forecasting

for i in range(shl_sm_parm_ccyy_mm_offset+50, shl_sm_parm_ccyy_mm_offset+51): # use csv data as simulation
    print('\n<<<< Record No.: %5d >>>>' % i)
    print(shl_sm_data['ccyy-mm'][i]) # format: ccyy-mm
    print(shl_sm_data['time'][i]) # format: hh:mm:ss
    print(shl_sm_data['bid-price'][i]) # format: integer/boost-trap-float
    
######################################################################################################################    
#   call prediction function, returned result is in 'list' format, i.e. [89400, 89400, 89400, 89500, 89500, 89500, 89500, 89600, 89600, 89600]  
    shl_sm_prediction_list_local_k = shl_pm.shl_predict_price_k_step(shl_sm_data['time'][i], shl_sm_data['bid-price'][i],10) # <- ten-step forward price forecasting
    print(shl_sm_prediction_list_local_k)
######################################################################################################################
# Out:
# <<<< Record No.:  2002 >>>>
# 2017-09
# 11:29:50
# 91500
# ==>> Forecasting   1 out of next  10 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:50
# in_current_price  : 91500.000000
# *INFO* f_current_datetime   : 2017-09 11:29:50
# *INFO* f_current_si         : 1.9280000000
# *INFO* f_current_price4pm   : 1101
# *INFO* f_current_price4pmsi : 571.0580912863
# *INFO* f_1_step_time        : 11:29:51
# *INFO* f_1_step_si          : 1.9980000000
# *INFO* sec50_error          : -19.9644548440
# *INFO* sec46_49_error       : -142.1982145745
# *INFO* shl_global_parm_short_weight_misc  : -32.4325338837
# *INFO* shl_global_parm_short_weight_ratio : 1
#      previous_pred_les_level  : 560.6379128558
#      previous_pred_les_trend  : 0.0651707313
#      f_1_step_pred_les_level  : 569.4926606183
#      f_1_step_pred_les_trend  : 0.0739603084
#      f_1_step_pred_les        : 569.5666209266
#      f_1_step_pred_adj_misc   : -0.6079051714
#      pred_les + pred_adj_misc : 568.9587157553
#      f_1_step_pred_price_inc          : 1136.7795140790
#      f_1_step_pred_price              : 91535.7795140790
#      f_1_step_pred_price_rounded      : 91500
#      f_1_step_pred_set_price_rounded  : 91800
# -------------------------------------------------
# ==>> Forecasting   2 out of next  10 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:51
# in_current_price  : 91535.779514
# *INFO* f_current_datetime   : 2017-09 11:29:51
# *INFO* f_current_si         : 1.9980000000
# *INFO* f_current_price4pm   : 1136
# *INFO* f_current_price4pmsi : 568.9587157553
# *INFO* f_1_step_time        : 11:29:52
# *INFO* f_1_step_si          : 2.0650000000
# *INFO* shl_global_parm_short_weight_ratio : 2
#      previous_pred_les_level  : 569.4926606183
#      previous_pred_les_trend  : 0.0739603084
#      f_1_step_pred_les_level  : 569.0506165463
#      f_1_step_pred_les_trend  : 0.0734443040
#      f_1_step_pred_les        : 569.1240608503
#      f_1_step_pred_adj_misc   : -1.2158103427
#      pred_les + pred_adj_misc : 567.9082505075
#      f_1_step_pred_price_inc          : 1172.7305372981
#      f_1_step_pred_price              : 91571.7305372981
#      f_1_step_pred_price_rounded      : 91600
#      f_1_step_pred_set_price_rounded  : 91900
# -------------------------------------------------
# ==>> Forecasting   3 out of next  10 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:52
# in_current_price  : 91571.730537
# *INFO* f_current_datetime   : 2017-09 11:29:52
# *INFO* f_current_si         : 2.0650000000
# *INFO* f_current_price4pm   : 1172
# *INFO* f_current_price4pmsi : 567.9082505075
# *INFO* f_1_step_time        : 11:29:53
# *INFO* f_1_step_si          : 2.1750000000
# *INFO* shl_global_parm_short_weight_ratio : 3
#      previous_pred_les_level  : 569.0506165463
#      previous_pred_les_trend  : 0.0734443040
#      f_1_step_pred_les_level  : 568.0920520896
#      f_1_step_pred_les_trend  : 0.0724122952
#      f_1_step_pred_les        : 568.1644643848
#      f_1_step_pred_adj_misc   : -1.8237155141
#      pred_les + pred_adj_misc : 566.3407488707
#      f_1_step_pred_price_inc          : 1231.7911287938
#      f_1_step_pred_price              : 91630.7911287938
#      f_1_step_pred_price_rounded      : 91600
#      f_1_step_pred_set_price_rounded  : 91900
# -------------------------------------------------
# ==>> Forecasting   4 out of next  10 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:53
# in_current_price  : 91630.791129
# *INFO* f_current_datetime   : 2017-09 11:29:53
# *INFO* f_current_si         : 2.1750000000
# *INFO* f_current_price4pm   : 1231
# *INFO* f_current_price4pmsi : 566.3407488707
# *INFO* f_1_step_time        : 11:29:54
# *INFO* f_1_step_si          : 2.2950000000
# *INFO* shl_global_parm_short_weight_ratio : 4
#      previous_pred_les_level  : 568.0920520896
#      previous_pred_les_trend  : 0.0724122952
#      f_1_step_pred_les_level  : 566.6164512437
#      f_1_step_pred_les_trend  : 0.0708642821
#      f_1_step_pred_les        : 566.6873155258
#      f_1_step_pred_adj_misc   : -2.4316206855
#      pred_les + pred_adj_misc : 564.2556948404
#      f_1_step_pred_price_inc          : 1294.9668196586
#      f_1_step_pred_price              : 91693.9668196586
#      f_1_step_pred_price_rounded      : 91700
#      f_1_step_pred_set_price_rounded  : 92000
# -------------------------------------------------
# ==>> Forecasting   5 out of next  10 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:54
# in_current_price  : 91693.966820
# *INFO* f_current_datetime   : 2017-09 11:29:54
# *INFO* f_current_si         : 2.2950000000
# *INFO* f_current_price4pm   : 1294
# *INFO* f_current_price4pmsi : 564.2556948404
# *INFO* f_1_step_time        : 11:29:55
# *INFO* f_1_step_si          : 2.4160000000
# *INFO* shl_global_parm_short_weight_ratio : 5
#      previous_pred_les_level  : 566.6164512437
#      previous_pred_les_trend  : 0.0708642821
#      f_1_step_pred_les_level  : 564.6232980044
#      f_1_step_pred_les_trend  : 0.0688002646
#      f_1_step_pred_les        : 564.6920982690
#      f_1_step_pred_adj_misc   : -3.0395258568
#      pred_les + pred_adj_misc : 561.6525724121
#      f_1_step_pred_price_inc          : 1356.9526149477
#      f_1_step_pred_price              : 91755.9526149477
#      f_1_step_pred_price_rounded      : 91800
#      f_1_step_pred_set_price_rounded  : 92100
# -------------------------------------------------
# ==>> Forecasting   6 out of next  10 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:55
# in_current_price  : 91755.952615
# *INFO* f_current_datetime   : 2017-09 11:29:55
# *INFO* f_current_si         : 2.4160000000
# *INFO* f_current_price4pm   : 1356
# *INFO* f_current_price4pmsi : 561.6525724121
# *INFO* f_1_step_time        : 11:29:56
# *INFO* f_1_step_si          : 2.5500000000
# *INFO* shl_global_parm_short_weight_ratio : 6
#      previous_pred_les_level  : 564.6232980044
#      previous_pred_les_trend  : 0.0688002646
#      f_1_step_pred_les_level  : 562.1120763672
#      f_1_step_pred_les_trend  : 0.0662202427
#      f_1_step_pred_les        : 562.1782966099
#      f_1_step_pred_adj_misc   : -3.6474310282
#      pred_les + pred_adj_misc : 558.5308655817
#      f_1_step_pred_price_inc          : 1424.2537072333
#      f_1_step_pred_price              : 91823.2537072332
#      f_1_step_pred_price_rounded      : 91800
#      f_1_step_pred_set_price_rounded  : 92100
# -------------------------------------------------
# ==>> Forecasting   7 out of next  10 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:56
# in_current_price  : 91823.253707
# *INFO* f_current_datetime   : 2017-09 11:29:56
# *INFO* f_current_si         : 2.5500000000
# *INFO* f_current_price4pm   : 1424
# *INFO* f_current_price4pmsi : 558.5308655817
# *INFO* f_1_step_time        : 11:29:57
# *INFO* f_1_step_si          : 2.7020000000
# *INFO* shl_global_parm_short_weight_ratio : 7
#      previous_pred_les_level  : 562.1120763672
#      previous_pred_les_trend  : 0.0662202427
#      f_1_step_pred_les_level  : 559.0822703278
#      f_1_step_pred_les_trend  : 0.0631242164
#      f_1_step_pred_les        : 559.1453945441
#      f_1_step_pred_adj_misc   : -4.2553361996
#      pred_les + pred_adj_misc : 554.8900583446
#      f_1_step_pred_price_inc          : 1499.3129376470
#      f_1_step_pred_price              : 91898.3129376470
#      f_1_step_pred_price_rounded      : 91900
#      f_1_step_pred_set_price_rounded  : 92200
# -------------------------------------------------
# ==>> Forecasting   8 out of next  10 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:57
# in_current_price  : 91898.312938
# *INFO* f_current_datetime   : 2017-09 11:29:57
# *INFO* f_current_si         : 2.7020000000
# *INFO* f_current_price4pm   : 1499
# *INFO* f_current_price4pmsi : 554.8900583446
# *INFO* f_1_step_time        : 11:29:58
# *INFO* f_1_step_si          : 2.7670000000
# *INFO* shl_global_parm_short_weight_ratio : 8
#      previous_pred_les_level  : 559.0822703278
#      previous_pred_les_trend  : 0.0631242164
#      f_1_step_pred_les_level  : 555.5333638817
#      f_1_step_pred_les_trend  : 0.0595121857
#      f_1_step_pred_les        : 555.5928760674
#      f_1_step_pred_adj_misc   : -4.8632413710
#      pred_les + pred_adj_misc : 550.7296346964
#      f_1_step_pred_price_inc          : 1523.8688992050
#      f_1_step_pred_price              : 91922.8688992050
#      f_1_step_pred_price_rounded      : 91900
#      f_1_step_pred_set_price_rounded  : 92200
# -------------------------------------------------
# ==>> Forecasting   9 out of next  10 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:58
# in_current_price  : 91922.868899
# *INFO* f_current_datetime   : 2017-09 11:29:58
# *INFO* f_current_si         : 2.7670000000
# *INFO* f_current_price4pm   : 1523
# *INFO* f_current_price4pmsi : 550.7296346964
# *INFO* f_1_step_time        : 11:29:59
# *INFO* f_1_step_si          : 2.9170000000
# *INFO* shl_global_parm_short_weight_ratio : 9
#      previous_pred_les_level  : 555.5333638817
#      previous_pred_les_trend  : 0.0595121857
#      f_1_step_pred_les_level  : 551.4648410246
#      f_1_step_pred_les_trend  : 0.0553841507
#      f_1_step_pred_les        : 551.5202251752
#      f_1_step_pred_adj_misc   : -5.4711465423
#      pred_les + pred_adj_misc : 546.0490786329
#      f_1_step_pred_price_inc          : 1592.8251623722
#      f_1_step_pred_price              : 91991.8251623722
#      f_1_step_pred_price_rounded      : 92000
#      f_1_step_pred_set_price_rounded  : 92300
# -------------------------------------------------
# ==>> Forecasting  10 out of next  10 seconds/steps...
#
# +-----------------------------------------------+
# | shl_predict_price_1_step()                    |
# +-----------------------------------------------+
# current_ccyy_mm   : 2017-09
# in_current_time   : 11:29:59
# in_current_price  : 91991.825162
# *INFO* f_current_datetime   : 2017-09 11:29:59
# *INFO* f_current_si         : 2.9170000000
# *INFO* f_current_price4pm   : 1592
# *INFO* f_current_price4pmsi : 546.0490786329
# *INFO* f_1_step_time        : 11:30:00
# *INFO* f_1_step_si          : 3.0570000000
# *INFO* shl_global_parm_short_weight_ratio : 10
#      previous_pred_les_level  : 551.4648410246
#      previous_pred_les_trend  : 0.0553841507
#      f_1_step_pred_les_level  : 546.8761857521
#      f_1_step_pred_les_trend  : 0.0507401113
#      f_1_step_pred_les        : 546.9269258633
#      f_1_step_pred_adj_misc   : -6.0790517137
#      pred_les + pred_adj_misc : 540.8478741496
#      f_1_step_pred_price_inc          : 1653.3719512754
#      f_1_step_pred_price              : 92052.3719512754
#      f_1_step_pred_price_rounded      : 92100
#      f_1_step_pred_set_price_rounded  : 92400
# -------------------------------------------------
# ==>> Prediction Restuls in Python List :  [91800, 91900, 91900, 92000, 92100, 92100, 92200, 92200, 92300, 92400]
# [91800, 91900, 91900, 92000, 92100, 92100, 92200, 92200, 92300, 92400]

# %%
print(shl_sm_prediction_list_local_k)
# Out:
# [91800, 91900, 91900, 92000, 92100, 92100, 92200, 92200, 92300, 92400]

# %%
shl_pm.shl_data_pm_1_step.tail(11)
# Out:
#     ccyy-mm  f_1_step_pred_adj_misc  f_1_step_pred_les  \
# 40  2017-09                0.000000         562.099852
# 41  2017-09                0.000000         544.613781
# 42  2017-09                0.000000         520.248608
# 43  2017-09                0.000000         478.430967
# 44  2017-09                0.000000         500.716823
# 45  2017-09                0.000000         487.470940
# 46  2017-09                0.000000         505.941000
# 47  2017-09                0.000000         541.167638
# 48  2017-09                0.000000         566.856015
# 49  2017-09                0.000000         560.703084
# 50  2017-09               -0.607905         569.566621
#
#     f_1_step_pred_les_level  f_1_step_pred_les_trend  f_1_step_pred_price  \
# 40               562.033037                 0.066815         91022.930836
# 41               544.564501                 0.049280         91033.475055
# 42               520.223718                 0.024890         91062.837224
# 43               478.447878                -0.016911         91063.540613
# 44               500.711453                 0.005370         91122.535809
# 45               487.478808                -0.007868         91165.791788
# 46               505.930409                 0.010591         91231.778885
# 47               541.121866                 0.045772         91347.125701
# 48               566.784626                 0.071389         91413.105410
# 49               560.637913                 0.065171         91480.035545
# 50               569.492661                 0.073960         91535.779514
#
#     f_1_step_pred_price_inc  f_1_step_pred_price_rounded  \
# 40               623.930836                      91000.0
# 41               634.475055                      91000.0
# 42               663.837224                      91100.0
# 43               664.540613                      91100.0
# 44               723.535809                      91100.0
# 45               766.791788                      91200.0
# 46               832.778885                      91200.0
# 47               948.125701                      91300.0
# 48              1014.105410                      91400.0
# 49              1081.035545                      91500.0
# 50              1136.779514                      91500.0
#
#     f_1_step_pred_set_price_rounded  f_1_step_si f_1_step_time  f_current_bid  \
# 40                          91300.0        1.110      11:29:41        91000.0
# 41                          91300.0        1.165      11:29:42        91000.0
# 42                          91400.0        1.276      11:29:43        91000.0
# 43                          91400.0        1.389      11:29:44        91000.0
# 41   2017-09 11:29:40          601.000000            558.550186         1.076
# 42   2017-09 11:29:41          601.000000            541.441441         1.110
# 43   2017-09 11:29:42          601.000000            515.879828         1.165
# 44   2017-09 11:29:43          601.000000            471.003135         1.276
# 45   2017-09 11:29:44          701.000000            504.679626         1.389
# 46   2017-09 11:29:45          701.000000            485.121107         1.445
# 47   2017-09 11:29:46          801.000000            509.218055         1.573
# 48   2017-09 11:29:47          901.000000            547.387606         1.646
# 49   2017-09 11:29:48         1001.000000            571.347032         1.752
# 50   2017-09 11:29:49         1001.000000            559.530464         1.789
# 51   2017-09 11:29:50         1101.000000            571.058091         1.928
# 52   2017-09 11:29:51         1136.779514            568.958716         1.998
# 53   2017-09 11:29:52         1172.730537            567.908251         2.065
# 54   2017-09 11:29:53         1231.791129            566.340749         2.175
# 55   2017-09 11:29:54         1294.966820            564.255695         2.295
# 56   2017-09 11:29:55         1356.952615            561.652572         2.416
# 57   2017-09 11:29:56         1424.253707            558.530866         2.550
# 58   2017-09 11:29:57         1499.312938            554.890058         2.702
# 59   2017-09 11:29:58         1523.868899            550.729635         2.767
# 60   2017-09 11:29:59         1592.825162            546.049079         2.917

# %%
# bid is predicted bid-price from shl_pm
plt.figure(figsize=(12,6))
plt.plot(shl_pm.shl_data_pm_k_step['f_current_bid'])
# plt.plot(shl_data_pm_1_step_k_step['f_1_step_pred_price'].shift(1))
plt.plot(shl_data_pm_k_step_local['f_1_step_pred_price'])

# bid is actual bid-price from raw dataset
shl_data_actual_bid_local = shl_sm_data[shl_sm_parm_ccyy_mm_offset:shl_sm_parm_ccyy_mm_offset+61].copy()
shl_data_actual_bid_local.reset_index(inplace=True)
plt.figure(figsize=(12,6))
plt.plot(shl_data_actual_bid_local['bid-price'])
plt.plot(shl_data_pm_k_step_local['f_1_step_pred_price'])

plt.figure(figsize=(12,6))
plt.plot(shl_data_actual_bid_local['bid-price'])
plt.plot(shl_data_pm_k_step_local['f_1_step_pred_price_rounded'])

# %%
print('Dynamic Increment : +%d' % shl_pm.shl_global_parm_dynamic_increment)
# Out:
# Dynamic Increment : +300

# %%
# pd.concat([shl_data_actual_bid_local['bid-price'], shl_data_pm_k_step_local['f_1_step_pred_price'], shl_data_pm_k_step_local['f_1_step_pred_price'] - shl_data_actual_bid_local['bid-price']], axis=1, join='inner')
pd.concat([shl_data_actual_bid_local['bid-price'].tail(11), shl_data_pm_k_step_local['f_1_step_pred_price'].tail(11), shl_data_pm_k_step_local['f_1_step_pred_price'].tail(11) - shl_data_actual_bid_local['bid-price'].tail(11)], axis=1, join='inner')
# Out:
#     bid-price  f_1_step_pred_price           0
# 50      91500         91480.035545  -19.964455
# 51      91600         91535.779514  -64.220486
# 52      91700         91571.730537 -128.269463
# 53      91800         91630.791129 -169.208871
# 54      91900         91693.966820 -206.033180
# 55      92000         91755.952615 -244.047385
# 56      92100         91823.253707 -276.746293
# 57      92100         91898.312938 -201.687062
# 58      92100         91922.868899 -177.131101
# 59      92200         91991.825162 -208.174838
# 60      92200         92052.371951 -147.628049

# %% [markdown]
# ### The End

# %% [markdown]
# ---
